# %% [markdown]
# # 1. Introduction Section:
# ## Discussion of the business problem and the audience who would be interested in this project.
# ## Description of the Problem and Background
# ## Scenario:
#
#     I am currently a Business student from University of Alberta (UA) and desire to figure out any possible business plans for fresh graduated students. University of Alberta (UA) is such an international academic institute in Edmonton that attract a lot of students from more than 100 countries every year. While hard to find jobs and work in domestic companies has been the challenge for most international students. Thus, more and more fresh graduated students decide to start up their own business. The restaurant is such a kind of business that easy to start and develop.
#
#     More and more people from other countries decide to live in Edmonton, which make the demographic composition becoming more and more comprehensive and diversified and bring more demands for different styles of food. However, the existing restaurants may not keep tracks on the changes on the demands.
#
#     My project will select the neighborhood around University of Alberta as the sample, aims to figure out where and what kinds of restaurants could be open to meet the needs for different food based on the changing trends of source of students. What is more, my project would also figure out whether existing some low-evaluated restaurants but good earning just because customers do not have other substitute restaurants.
#
# ## Business Problem:
#     To identify whether the existing restaurants could meet the demands for more and more kinds of food as the demographic composition in Edmonton has been more comprehensive and diversified.
#     To figure whether existing some low-evaluated restaurants could be replaced.
#
# ## Interested Audience
#     The fresh international graduated students who would like to start up their first business.
#     The new immigrates who would like to start up their first business in Canada.

# %% [markdown]
# # 2. Data Section:
# ## Description of the data and its sources that will be used to solve the problem
#
# ## The data will be used as follows:
#
#     A table with the data about the borough, neighborhood and postal codes: This table would be scraped from Wikipedia and well organized in order to get the specific location data for Edmonton. In this project, I would use X-path package to scrape data.
#
#     A table with the data about each borough’s coordinates data: This table would use the above table as the input to find out corresponding coordinates data. The table could provide the required information to map each region point. I would use geopy package to catch their coordinates data.
#
#     A table with the data about the existing restaurant’s types, location, evaluation etc.: This table would contain the information existing restaurant’s types, location, evaluation to help me analyze the current situation and figure whether existing low-evaluated restaurants could be replaced by new ones. I would use Foursquare API to get the data.
#
#     A table with the data about the source of students in University of Alberta: This table would help me contain the information about the changing trends of source of students in University of Alberta.
#
#     I would use K-means to divide all the restaurants into different clusters and try to figure out the whether the existing types of restaurants could meet the needs for recent or even the future students. I would also try to use K-means to figure out what kinds of restaurants with low evaluation should be improved by the entering of new competitors.

# %%
# !pip install lxml

# %%
#1.Scraping data from Wiki Pedia
    
#1.1 import required modules
import requests
from lxml import etree
import pandas as pd

#1.2 set url and headers
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_T"

headers = {
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:90.0) Gecko/20100101 Firefox/90.0",
            }
    
#1.3 get html strings
response = requests.get(url,headers = headers)
content = response.content.decode("utf8")

#1.4 etree parse
html = etree.HTML(content)

# %%
#1.5 Xpath extract data
# /html/body/div[3]/div[3]/div[5]/div[1]/table[1]/tbody/tr[1]/td[3]/b
trs = html.xpath("///body/div[3]/div[3]/div[5]/div[1]/table[1]/tbody/tr")
#an empty list to input the dic-s
dic_list = []
for tr in trs:
    temp_dic = {}#temp dic for put values
    tds = tr.xpath("./td")
    for td in tds:
        Postalcode = td.xpath("./b/text()[1]")
        Borough = td.xpath("./span/a[1]/text()")
        Neighborhood = td.xpath("./span/a/text()")[1:] # because the first item is the borough name
        
        
        
        #to convert list elements of Neighborhood into str seperated by, 
        temp_str = ""
        if Neighborhood != []:
            counter = len(Neighborhood)
            for each in Neighborhood:
                counter -= 1
                temp_str = temp_str + each 
                if counter > 1:
                    temp_str = temp_str +  ", "
            Neighborhood = temp_str
         #to convert list elements of Neighborhood into str seperated by, 
        
        
        
        temp_dic = {
                "Postalcode":Postalcode,
                "Borough":Borough,
                "Neighborhood":Neighborhood, #since we may have one more items in the list 
                }
        dic_list.append(temp_dic)

dic_list
# Out:
# [{'Postalcode': ['T1A'], 'Borough': ['Medicine Hat'], 'Neighborhood': []},
#  {'Postalcode': ['T2A'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Penbrooke MeadowsMarlborough'},
#  {'Postalcode': ['T3A'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Dalhousie, Edgemont, HamptonsHidden Valley'},
#  {'Postalcode': ['T4A'], 'Borough': ['Airdrie'], 'Neighborhood': []},
#  {'Postalcode': ['T5A'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'ClareviewLondonderry'},
#  {'Postalcode': ['T6A'], 'Borough': ['Edmonton'], 'Neighborhood': 'Capilano'},
#  {'Postalcode': ['T7A'], 'Borough': ['Drayton Valley'], 'Neighborhood': []},
#  {'Postalcode': ['T8A'], 'Borough': ['Sherwood Park'], 'Neighborhood': []},
#  {'Postalcode': ['T9A'], 'Borough': ['Wetaskiwin'], 'Neighborhood': []},
#  {'Postalcode': ['T1B'], 'Borough': ['Medicine Hat'], 'Neighborhood': []},
#  {'Postalcode': ['T2B'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Forest Lawn, DoverErin Woods'},
#  {'Postalcode': ['T3B'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Montgomery, Bowness, Silver SpringsGreenwood'},
#  {'Postalcode': ['T4B'], 'Borough': ['Airdrie'], 'Neighborhood': []},
#  {'Postalcode': ['T5B'], 'Borough': ['Edmonton'], 'Neighborhood': 'Beverly'},
#  {'Postalcode': ['T6B'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'Capilano, Southeast IndustrialBonnie Doon'},
#  {'Postalcode': ['T7B'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T8B'], 'Borough': ['Sherwood Park'], 'Neighborhood': []},
#  {'Postalcode': ['T9B'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T1C'], 'Borough': ['Medicine Hat'], 'Neighborhood': []},
#  {'Postalcode': ['T2C'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Lynnwood Ridge, Ogden, Foothills IndustrialGreat Plains'},
#  {'Postalcode': ['T3C'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Rosscarrock, Westgate, Wildwood, ShaganappiSunalta'},
#  {'Postalcode': ['T4C'], 'Borough': ['Cochrane'], 'Neighborhood': []},
#  {'Postalcode': ['T5C'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'Londonderry'},
#  {'Postalcode': ['T6C'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'Bonnie Doon'},
#  {'Postalcode': ['T7C'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T8C'], 'Borough': ['Sherwood Park'], 'Neighborhood': []},
#  {'Postalcode': ['T9C'], 'Borough': ['Vegreville'], 'Neighborhood': []},
#  {'Postalcode': ['T1E'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T2E'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Bridgeland, Greenview, ZooYYC'},
#  {'Postalcode': ['T3E'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Lakeview, Glendale, KillarneyGlamorgan'},
#  {'Postalcode': ['T4E'], 'Borough': ['Red Deer County'], 'Neighborhood': []},
#  {'Postalcode': ['T5E'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'LondonderryCalder'},
#  {'Postalcode': ['T6E'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'Bonnie DoonUniversity'},
#  {'Postalcode': ['T7E'], 'Borough': ['Edson'], 'Neighborhood': []},
#  {'Postalcode': ['T8E'], 'Borough': ['Sherwood Park'], 'Neighborhood': []},
#  {'Postalcode': ['T9E'], 'Borough': ['Leduc'], 'Neighborhood': 'YEG'},
#  {'Postalcode': ['T1G'], 'Borough': ['Taber'], 'Neighborhood': []},
#  {'Postalcode': ['T2G'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Inglewood, Burnsland, Chinatown, Victoria ParkSaddledome'},
#  {'Postalcode': ['T3G'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Hawkwood, Arbour Lake, Citadel, Ranchlands, Royal OakRocky Ridge'},
#  {'Postalcode': ['T4G'], 'Borough': ['Innisfail'], 'Neighborhood': []},
#  {'Postalcode': ['T5G'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'Queen Mary ParkBlatchford)'},
#  {'Postalcode': ['T6G'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'UniversityStrathcona Place'},
#  {'Postalcode': ['T7G'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T8G'], 'Borough': ['Sherwood Park'], 'Neighborhood': []},
#  {'Postalcode': ['T9G'], 'Borough': ['Devon'], 'Neighborhood': []},
#  {'Postalcode': ['T1H'], 'Borough': ['Lethbridge'], 'Neighborhood': []},
#  {'Postalcode': ['T2H'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'HighfieldBurns Industrial'},
#  {'Postalcode': ['T3H'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Discovery Ridge, Signal Hill, West Springs, Christie Park, PattersonCougar Ridge'},
#  {'Postalcode': ['T4H'], 'Borough': ['Olds'], 'Neighborhood': []},
#  {'Postalcode': ['T5H'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'Downtown Fringe'},
#  {'Postalcode': ['T6H'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'SouthgateRiverbend'},
#  {'Postalcode': ['T7H'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T8H'], 'Borough': ['Sherwood Park'], 'Neighborhood': []},
#  {'Postalcode': ['T9H'], 'Borough': ['Fort McMurray'], 'Neighborhood': []},
#  {'Postalcode': ['T1J'], 'Borough': ['Lethbridge'], 'Neighborhood': []},
#  {'Postalcode': ['T2J'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Queensland, Lake Bonavista, Willow ParkAcadia'},
#  {'Postalcode': ['T3J'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Martindale, Taradale, FalconridgeSaddle Ridge'},
#  {'Postalcode': ['T4J'], 'Borough': ['Ponoka'], 'Neighborhood': []},
#  {'Postalcode': ['T5J'], 'Borough': ['Edmonton'], 'Neighborhood': 'Downtown'},
#  {'Postalcode': ['T6J'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'KaskitayoAspen Gardens'},
#  {'Postalcode': ['T7J'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T8J'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T9J'], 'Borough': ['Fort McMurray'], 'Neighborhood': []},
#  {'Postalcode': ['T1K'], 'Borough': ['Lethbridge'], 'Neighborhood': []},
#  {'Postalcode': ['T2K'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'ThorncliffeTuxedo Park'},
#  {'Postalcode': ['T3K'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Sandstone, MacEwan Glen, Beddington, Harvest Hills, Coventry HillsPanorama Hills'},
#  {'Postalcode': ['T4K'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T5K'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'DowntownDowntown Fringe'},
#  {'Postalcode': ['T6K'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'Mill Woods'},
#  {'Postalcode': ['T7K'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T8K'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T9K'], 'Borough': ['Fort McMurray'], 'Neighborhood': []},
#  {'Postalcode': ['T1L'], 'Borough': ['Banff'], 'Neighborhood': []},
#  {'Postalcode': ['T2L'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Brentwood, CollingwoodNose Hill'},
#  {'Postalcode': ['T3L'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'TuscanyScenic Acres'},
#  {'Postalcode': ['T4L'], 'Borough': ['Lacombe'], 'Neighborhood': []},
#  {'Postalcode': ['T5L'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'Westmount, CalderMistatim'},
#  {'Postalcode': ['T6L'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'Mill Woods'},
#  {'Postalcode': ['T7L'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T8L'], 'Borough': ['Fort Saskatchewan'], 'Neighborhood': []},
#  {'Postalcode': ['T9L'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T1M'], 'Borough': ['Coaldale'], 'Neighborhood': []},
#  {'Postalcode': ['T2M'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Mount Pleasant, Capitol HillBanff Trail'},
#  {'Postalcode': ['T3M'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Cranston, Auburn BayMahogany'},
#  {'Postalcode': ['T4M'], 'Borough': ['Blackfalds'], 'Neighborhood': []},
#  {'Postalcode': ['T5M'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'Westmount, Groat EstateNorthwest Industrial'},
#  {'Postalcode': ['T6M'], 'Borough': ['Edmonton'], 'Neighborhood': []},
#  {'Postalcode': ['T7M'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T8M'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T9M'], 'Borough': ['Cold Lake'], 'Neighborhood': []},
#  {'Postalcode': ['T1N'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T2N'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Kensington, Westmont, ParkdaleUniversity'},
#  {'Postalcode': ['T3N'], 'Borough': ['Calgary'], 'Neighborhood': []},
#  {'Postalcode': ['T4N'], 'Borough': ['Red Deer'], 'Neighborhood': []},
#  {'Postalcode': ['T5N'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'GlenoraDowntown Fringe'},
#  {'Postalcode': ['T6N'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'South Industrial'},
#  {'Postalcode': ['T7N'], 'Borough': ['Barrhead'], 'Neighborhood': []},
#  {'Postalcode': ['T8N'], 'Borough': ['St. Albert'], 'Neighborhood': []},
#  {'Postalcode': ['T9N'], 'Borough': ['Bonnyville'], 'Neighborhood': []},
#  {'Postalcode': ['T1P'], 'Borough': ['Strathmore'], 'Neighborhood': []},
#  {'Postalcode': ['T2P'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'City CentreCalgary Tower'},
#  {'Postalcode': ['T3P'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Symons Valley'},
#  {'Postalcode': ['T4P'], 'Borough': ['Red Deer'], 'Neighborhood': []},
#  {'Postalcode': ['T5P'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'Jasper Place'},
#  {'Postalcode': ['T6P'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'Southeast IndustrialClover Bar'},
#  {'Postalcode': ['T7P'], 'Borough': ['Westlock'], 'Neighborhood': []},
#  {'Postalcode': ['T8P'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T9P'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T1R'], 'Borough': ['Brooks'], 'Neighborhood': []},
#  {'Postalcode': ['T2R'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'ConnaughtVictoria Park'},
#  {'Postalcode': ['T3R'], 'Borough': ['Calgary'], 'Neighborhood': []},
#  {'Postalcode': ['T4R'], 'Borough': ['Red Deer'], 'Neighborhood': []},
#  {'Postalcode': ['T5R'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'Jasper PlaceBuena Vista'},
#  {'Postalcode': ['T6R'], 'Borough': ['Edmonton'], 'Neighborhood': 'Riverbend'},
#  {'Postalcode': ['T7R'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T8R'], 'Borough': ['Morinville'], 'Neighborhood': []},
#  {'Postalcode': ['T9R'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T1S'], 'Borough': ['Okotoks'], 'Neighborhood': []},
#  {'Postalcode': ['T2S'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Elbow Park, Britannia, ParkhillMission'},
#  {'Postalcode': ['T3S'], 'Borough': ['Calgary'], 'Neighborhood': []},
#  {'Postalcode': ['T4S'], 'Borough': ['Sylvan Lake'], 'Neighborhood': []},
#  {'Postalcode': ['T5S'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'Northwest IndustrialWinterburn'},
#  {'Postalcode': ['T6S'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'Clover Bar'},
#  {'Postalcode': ['T7S'], 'Borough': ['Whitecourt'], 'Neighborhood': []},
#  {'Postalcode': ['T8S'], 'Borough': ['Peace River'], 'Neighborhood': []},
#  {'Postalcode': ['T9S'], 'Borough': ['Athabasca'], 'Neighborhood': []},
#  {'Postalcode': ['T1T'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T2T'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Altadore, BankviewRichmond'},
#  {'Postalcode': ['T3T'], 'Borough': ["Tsuut'ina"], 'Neighborhood': []},
#  {'Postalcode': ['T4T'],
#   'Borough': ['Rocky Mountain House'],
#   'Neighborhood': []},
#  {'Postalcode': ['T5T'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'West Jasper PlaceWest Edmonton Mall'},
#  {'Postalcode': ['T6T'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'The Meadows'},
#  {'Postalcode': ['T7T'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T8T'], 'Borough': ['Sturgeon County'], 'Neighborhood': []},
#  {'Postalcode': ['T9T'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T1V'], 'Borough': ['High River'], 'Neighborhood': []},
#  {'Postalcode': ['T2V'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Oak Ridge, Haysboro, Kingsland, Kelvin GroveWindsor Park'},
#  {'Postalcode': ['T3V'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T4V'], 'Borough': ['Camrose'], 'Neighborhood': []},
#  {'Postalcode': ['T5V'], 'Borough': ['Edmonton'], 'Neighborhood': 'Mistatim'},
#  {'Postalcode': ['T6V'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'The PalisadesCastle Downs'},
#  {'Postalcode': ['T7V'], 'Borough': ['Hinton'], 'Neighborhood': []},
#  {'Postalcode': ['T8V'], 'Borough': ['Grande Prairie'], 'Neighborhood': []},
#  {'Postalcode': ['T9V'], 'Borough': ['Lloydminster'], 'Neighborhood': []},
#  {'Postalcode': ['T1W'], 'Borough': ['Canmore'], 'Neighborhood': []},
#  {'Postalcode': ['T2W'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Braeside, CedarbraeWoodbine'},
#  {'Postalcode': ['T3W'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T4W'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T5W'], 'Borough': ['Edmonton'], 'Neighborhood': 'Beverly'},
#  {'Postalcode': ['T6W'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'Heritage Valley'},
#  {'Postalcode': ['T7W'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T8W'], 'Borough': ['Grande Prairie'], 'Neighborhood': []},
#  {'Postalcode': ['T9W'], 'Borough': ['Wainwright'], 'Neighborhood': []},
#  {'Postalcode': ['T1X'], 'Borough': ['Chestermere'], 'Neighborhood': []},
#  {'Postalcode': ['T2X'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'MidnaporeSundance'},
#  {'Postalcode': ['T3X'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T4X'], 'Borough': ['Beaumont'], 'Neighborhood': []},
#  {'Postalcode': ['T5X'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'Castle Downs'},
#  {'Postalcode': ['T6X'], 'Borough': ['Edmonton'], 'Neighborhood': 'Ellerslie'},
#  {'Postalcode': ['T7X'], 'Borough': ['Spruce Grove'], 'Neighborhood': []},
#  {'Postalcode': ['T8X'], 'Borough': ['Grande Prairie'], 'Neighborhood': []},
#  {'Postalcode': ['T9X'], 'Borough': ['Vermilion'], 'Neighborhood': []},
#  {'Postalcode': ['T1Y'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Rundle, WhitehornMonterey Park'},
#  {'Postalcode': ['T2Y'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Millrise, Somerset, BridlewoodEvergreen'},
#  {'Postalcode': ['T3Y'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T4Y'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T5Y'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'Horse HillLake District'},
#  {'Postalcode': ['T6Y'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'Southeast Edmonton'},
#  {'Postalcode': ['T7Y'],
#   'Borough': ['Spruce Grove'],
#   'Neighborhood': 'Parkland CountyCarvel'},
#  {'Postalcode': ['T8Y'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T9Y'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T1Z'], 'Borough': ['Rocky View'], 'Neighborhood': []},
#  {'Postalcode': ['T2Z'],
#   'Borough': ['Calgary'],
#   'Neighborhood': 'Douglas Glen, McKenzie Lake, CopperfieldEast Shepard'},
#  {'Postalcode': ['T3Z'], 'Borough': ['Redwood Meadows'], 'Neighborhood': []},
#  {'Postalcode': ['T4Z'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T5Z'],
#   'Borough': ['Edmonton'],
#   'Neighborhood': 'Lake District'},
#  {'Postalcode': ['T6Z'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T7Z'], 'Borough': ['Stony Plain'], 'Neighborhood': []},
#  {'Postalcode': ['T8Z'], 'Borough': [], 'Neighborhood': []},
#  {'Postalcode': ['T9Z'], 'Borough': [], 'Neighborhood': []}]

# %%
# creat a new Dataframe
columns= ['Postalcode','Borough','Neighborhood']
df_edm = pd.DataFrame(columns = columns,data = dic_list)
df_edm
# Out:
#     Postalcode         Borough                                Neighborhood
# 0        [T1A]  [Medicine Hat]                                          []
# 1        [T2A]       [Calgary]                Penbrooke MeadowsMarlborough
# 2        [T3A]       [Calgary]  Dalhousie, Edgemont, HamptonsHidden Valley
# 3        [T4A]       [Airdrie]                                          []
# 4        [T5A]      [Edmonton]                        ClareviewLondonderry
# ..         ...             ...                                         ...
# 175      [T5Z]      [Edmonton]                               Lake District
# 176      [T6Z]              []                                          []
# 177      [T7Z]   [Stony Plain]                                          []
# 178      [T8Z]              []                                          []
# 179      [T9Z]              []                                          []
#
# [180 rows x 3 columns]

# %%
#get the value from the [list]
df_edm["Postalcode"] = df_edm["Postalcode"].apply(lambda x:x[0]) 
#get the value from the [list] and make all the [] into ""
df_edm["Borough"] = df_edm["Borough"].apply(lambda x:x[0]if x != [] else "") 
#make all the [] into ""
df_edm["Neighborhood"] = df_edm["Neighborhood"].apply(lambda x:x if x != [] else "")

# %%
#clean all the empty string: ""
df_edm = df_edm[df_edm["Borough"]!= ""]
df_edm = df_edm[df_edm["Neighborhood"]!= ""]

# %%
df_edm = df_edm.reset_index(drop = True)
df_edm.shape
# Out:
# (72, 3)

# %%
df_edm
# Out:
#    Postalcode       Borough                                       Neighborhood
# 0         T2A       Calgary                       Penbrooke MeadowsMarlborough
# 1         T3A       Calgary         Dalhousie, Edgemont, HamptonsHidden Valley
# 2         T5A      Edmonton                               ClareviewLondonderry
# 3         T6A      Edmonton                                           Capilano
# 4         T2B       Calgary                       Forest Lawn, DoverErin Woods
# ..        ...           ...                                                ...
# 67        T5Y      Edmonton                            Horse HillLake District
# 68        T6Y      Edmonton                                 Southeast Edmonton
# 69        T7Y  Spruce Grove                              Parkland CountyCarvel
# 70        T2Z       Calgary  Douglas Glen, McKenzie Lake, CopperfieldEast S...
# 71        T5Z      Edmonton                                      Lake District
#
# [72 rows x 3 columns]

# %%
# !pip install geocoder
# Out:
# Requirement already satisfied: geocoder in c:\programdata\anaconda3\lib\site-packages (1.38.1)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from geocoder) (7.1.2)
# Requirement already satisfied: ratelim in c:\programdata\anaconda3\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from geocoder) (2.25.1)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from geocoder) (1.15.0)
# Requirement already satisfied: future in c:\programdata\anaconda3\lib\site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ratelim->geocoder) (5.0.6)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->geocoder) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->geocoder) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->geocoder) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->geocoder) (1.26.4)

# %%
import geocoder #free and faster API to get coordinates data

# define the function get_coords to get latt 
def get_coords(postal_code):

    coords = None

    while(coords == None):

        geocoder_1 = geocoder.arcgis('%s, Edmonton, Alberta'%format(postal_code))

        coords = geocoder_1.latlng

    return coords
#reference:https://www.coursera.org/learn/applied-data-science-capstone/discussions/all/threads/GUbn5pVFEemtYQ4WTQex_A

# %%
# get_coords("T3A")
# Out:
# [53.54624000000007, -113.49036999999998]

# %%
#set the list for catch temp_dic 
coords_list = []
Postalcodes_list = df_edm["Postalcode"].tolist()
# print(Postalcodes_list)

for each in Postalcodes_list:
#     print(each)
    temp_dic = {}
    temp_coord = get_coords(each) 
    longitude = temp_coord[1]
    latitude = temp_coord[0]
    temp_dic = {
                "Postalcode":each,
                "latitude":latitude,
                "longitude":longitude,
                }
    coords_list.append(temp_dic)
#     break

df_edm_coords = pd.DataFrame(coords_list)
print("finished!!!!!!!!!")
# Out:
# finished!!!!!!!!!

# %%
df_edm_coords
# Out:
#    Postalcode  latitude  longitude
# 0         T2A  53.54624 -113.49037
# 1         T3A  53.54624 -113.49037
# 2         T5A  53.59443 -113.40844
# 3         T6A  53.55094 -113.43550
# 4         T2B  53.54624 -113.49037
# ..        ...       ...        ...
# 67        T5Y  53.65196 -113.35747
# 68        T6Y  53.36686 -113.60763
# 69        T7Y  53.49069 -114.14729
# 70        T2Z  53.54624 -113.49037
# 71        T5Z  53.63227 -113.46744
#
# [72 rows x 3 columns]

# %%
df_merge = pd.merge(df_edm,df_edm_coords, on = "Postalcode")
df_merge
# df_merge.to_csv("week3_df_merge.csv")
# Out:
#    Postalcode       Borough  \
# 0         T2A       Calgary
# 1         T3A       Calgary
# 2         T5A      Edmonton
# 3         T6A      Edmonton
# 4         T2B       Calgary
# ..        ...           ...
# 67        T5Y      Edmonton
# 68        T6Y      Edmonton
# 69        T7Y  Spruce Grove
# 70        T2Z       Calgary
# 71        T5Z      Edmonton
#
#                                          Neighborhood  latitude  longitude
# 0                        Penbrooke MeadowsMarlborough  53.54624 -113.49037
# 1          Dalhousie, Edgemont, HamptonsHidden Valley  53.54624 -113.49037
# 2                                ClareviewLondonderry  53.59443 -113.40844
# 3                                            Capilano  53.55094 -113.43550
# 4                        Forest Lawn, DoverErin Woods  53.54624 -113.49037
# ..                                                ...       ...        ...
# 67                            Horse HillLake District  53.65196 -113.35747
# 68                                 Southeast Edmonton  53.36686 -113.60763
# 69                              Parkland CountyCarvel  53.49069 -114.14729
# 70  Douglas Glen, McKenzie Lake, CopperfieldEast S...  53.54624 -113.49037
# 71                                      Lake District  53.63227 -113.46744
#
# [72 rows x 5 columns]

# %%
# show the basic information of Toronto
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(df_merge['Borough'].unique()),
        df_merge.shape[0]
    )
)
# Out:
# The dataframe has 4 boroughs and 72 neighborhoods.

# %%
#install required packages
# !pip install geopy
# !pip install folium==0.5.0
# Out:
# Requirement already satisfied: geopy in c:\programdata\anaconda3\lib\site-packages (2.2.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\programdata\anaconda3\lib\site-packages (from geopy) (1.52)
# Requirement already satisfied: folium==0.5.0 in c:\programdata\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from folium==0.5.0) (2.25.1)
# Requirement already satisfied: branca in c:\programdata\anaconda3\lib\site-packages (from folium==0.5.0) (0.4.2)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from folium==0.5.0) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->folium==0.5.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->folium==0.5.0) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->folium==0.5.0) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->folium==0.5.0) (4.0.0)

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
#get the coordinates inf of Toronto
geocoder_Edm = geocoder.arcgis('Edmonton, Alberta')

coords_Edm = geocoder_Edm.latlng
coords_Edm
# Out:
# [53.54624000000007, -113.49036999999998]

# %%
# create map of Toronto using latitude and longitude values
map_Edm = folium.Map(location=[coords_Edm[0], coords_Edm[1]], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_merge['latitude'], df_merge['longitude'], df_merge['Borough'], df_merge['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False
                        ).add_to(map_Edm) 

map_Edm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_2b0e420f8b4740e19d71b06ddbf02f5d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2b0e420f8b4740e19d71b06ddbf02f5d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2b0e420f8b4740e19d71b06ddbf02f5d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_2b0e420f8b4740e19d71b06ddbf02f5d%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B53.54624000000007%2C-113.49036999999998%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%2 ...
